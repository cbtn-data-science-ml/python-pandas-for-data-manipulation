# %% [markdown]
# # `.isnull()` and `.notnull()`

# %% [markdown]
# ### Import pandas

# %%
# import pandas

# %% [markdown]
# ### Read CSV

# %%
# Out:
#   first_name   last_name  salary  start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473    5/9/2020       NaN    True   management
# 1    Coretta      McEvon  637457   3/20/2020      Male   False  engineering
# 2   Clarette     Tarbett  977749  11/22/2020   Agender    True  engineering
# 3      Jaime  Gianneschi  253523    9/2/2020  Bigender   False    marketing
# 4      Ediva     Skelton  325185    2/4/2020    Female    True    marketing

# %% [markdown]
# ### `.isnull()`

# %%
# Out:
# 0              NaN
# 1             Male
# 2          Agender
# 3         Bigender
# 4           Female
#           ...
# 995     Polygender
# 996    Genderfluid
# 997    Genderqueer
# 998         Female
# 999     Polygender
# Name: gender, Length: 1000, dtype: object

# %%
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
# return all of the rows containing null values in the gender column
# Out:
#      first_name     last_name  salary  start_date gender  remote  \
# 0       Haleigh    Calderhead  334473    5/9/2020    NaN    True
# 7         Sarah       Feather  553617    4/5/2020    NaN    True
# 10         Gray     Ghirigori  972661   5/29/2020    NaN   False
# 11      Malissa       Billett  492837    9/1/2020    NaN   False
# 68     Ursuline      Surfleet  631021   8/11/2020    NaN    True
# 84       Cecile   Jerzycowski  987315   9/23/2020    NaN    True
# 119        Mike  Sommerscales  264558  12/26/2020    NaN   False
# 129       Hyman           Bye  758704  10/29/2020    NaN   False
# 138       Randa        Visick  114061    5/4/2020    NaN   False
# 143      Hamnet       Wipfler  284895    5/5/2020    NaN   False
# 173       Carma       Matejka  882031   4/30/2020    NaN    True
# 201       Datha        Leyban  256662   2/16/2020    NaN   False
# 336    Bernette     Scrigmour  591366   8/11/2020    NaN    True
# 351        Kory          Hovy  426422   10/5/2020    NaN    True
# 404       Jobye        Worton  866288   1/12/2021    NaN    True
# 411    Pamelina     Ionnisian  327376   8/21/2020    NaN   False
# 438        Nial     Gellately  118721    6/2/2020    NaN    True
# 478       Gordy       Doberer  923441   12/1/2020    NaN    True
# 493       Melly       Bowcher  844783    6/7/2020    NaN    True
# 571     Bartlet        Cloney  457105   1/15/2021    NaN   False
# 617       Jonis         Niblo  564427   3/20/2020    NaN    True
# 649      Wallie        Solley  821141  11/27/2020    NaN    True
# 672       Bruis       Wegenen  187305    2/5/2020    NaN    True
# 708        Keir         Alfwy  649521   7/13/2020    NaN    True
# 713      Junina          Witt  223298   2/13/2020    NaN   False
# 733      Kellie         Hayen  627035    3/5/2020    NaN   False
# 736       Paxon      Pibworth  544187   7/11/2020    NaN   False
# 745      Sigrid        Lepere  305346   4/13/2020    NaN   False
# 746       Cosme         Romeo  714000   2/13/2020    NaN    True
# 833       Salim        Triner  623813   9/22/2020    NaN   False
# 907  Clarabelle     Goodbanne  853440  10/27/2020    NaN   False
# 932      Roxine        Arnely  484685    5/9/2020    NaN    True
# 937     Hermine     Flippelli  905976    4/5/2020    NaN    True
# 986      Audrie   Muddicliffe  274804   2/16/2020    NaN   False
#
#                team
# 0        management
# 7    data analytics
# 10        marketing
# 11       management
# 68   data analytics
# 84   data analytics
# 119      management
# 129  data analytics
# 138       marketing
# 143      management
# 173  data analytics
# 201     engineering
# 336  data analytics
# 351       marketing
# 404      management
# 411       marketing
# 438     engineering
# 478      management
# 493      management
# 571  data analytics
# 617  data analytics
# 649       marketing
# 672       marketing
# 708       marketing
# 713     engineering
# 733     engineering
# 736  data analytics
# 745       marketing
# 746      management
# 833  data analytics
# 907       marketing
# 932     engineering
# 937       marketing
# 986      management

# %%
# Out:
# first_name    34
# last_name     34
# salary        34
# start_date    34
# gender         0
# remote        34
# team          34
# dtype: int64

# %% [markdown]
# ### `.notnull()`

# %%
# Out:
# 0              NaN
# 1             Male
# 2          Agender
# 3         Bigender
# 4           Female
#           ...
# 995     Polygender
# 996    Genderfluid
# 997    Genderqueer
# 998         Female
# 999     Polygender
# Name: gender, Length: 1000, dtype: object

# %%
# return all of the rows without null values in the gender column
# Out:
#     first_name   last_name  salary  start_date       gender  remote  \
# 0      Haleigh  Calderhead  334473    5/9/2020          NaN    True
# 1      Coretta      McEvon  637457   3/20/2020         Male   False
# 2     Clarette     Tarbett  977749  11/22/2020      Agender    True
# 3        Jaime  Gianneschi  253523    9/2/2020     Bigender   False
# 4        Ediva     Skelton  325185    2/4/2020       Female    True
# ..         ...         ...     ...         ...          ...     ...
# 995     Ysabel  Stollmeyer  649625  10/18/2020   Polygender   False
# 996      Ashby  Threadgold  140806  12/28/2020  Genderfluid   False
# 997    Justino     Asquith  950280  10/26/2020  Genderqueer   False
# 998     Jerald     Penella  862555    9/8/2020       Female   False
# 999     Aubrie        Hunt  549364   3/29/2020   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# ..              ...
# 995      management
# 996      management
# 997      management
# 998     engineering
# 999  data analytics
#
# [1000 rows x 7 columns]

# %%
# return all of the rows without null values
# Out:
#     first_name   last_name  salary  start_date       gender  remote  \
# 0      Haleigh  Calderhead  334473    5/9/2020          NaN    True
# 1      Coretta      McEvon  637457   3/20/2020         Male   False
# 2     Clarette     Tarbett  977749  11/22/2020      Agender    True
# 3        Jaime  Gianneschi  253523    9/2/2020     Bigender   False
# 4        Ediva     Skelton  325185    2/4/2020       Female    True
# ..         ...         ...     ...         ...          ...     ...
# 995     Ysabel  Stollmeyer  649625  10/18/2020   Polygender   False
# 996      Ashby  Threadgold  140806  12/28/2020  Genderfluid   False
# 997    Justino     Asquith  950280  10/26/2020  Genderqueer   False
# 998     Jerald     Penella  862555    9/8/2020       Female   False
# 999     Aubrie        Hunt  549364   3/29/2020   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# ..              ...
# 995      management
# 996      management
# 997      management
# 998     engineering
# 999  data analytics
#
# [1000 rows x 7 columns]
