# %% [markdown]
# # Rename index labels and column labels

# %% [markdown]
# ### Import pandas

# %%
# Import pandas

# %% [markdown]
# ### Read CSV and set rating index sorted by labels

# %%
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Rename index label

# %%
# view documentation and use mapper

# %%
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Multiple labels

# %%
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Tricks                      G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Instead of mapper you can use index

# %%
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Rename column headers

# %%
# cereal.rename(mapper = {"mfr":"manufacturer"}, axis=1)
# cereal.rename(mapper = {"mfr":"manufacturer"}, axis="columns")
cereal.rename(columns = {"mfr":"manufacturer"})
# Out:
#                           manufacturer type  calories  protein  fat  sodium  \
# name
# 100% Bran                            N    C        70        4    1     130
# 100% Natural Bran                    Q    C       120        3    5      15
# All-Bran                             K    C        70        4    1     260
# All-Bran with Extra Fiber            K    C        50        4    0     140
# Almond Delight                       R    C       110        2    2     200
# ...                                ...  ...       ...      ...  ...     ...
# Triples                              G    C       110        2    1     250
# Trix                                 G    C       110        1    1     140
# Wheat Chex                           R    C       100        3    1     230
# Wheaties                             G    C       100        3    1     200
# Wheaties Honey Gold                  G    C       110        2    1     200
#
# ...
