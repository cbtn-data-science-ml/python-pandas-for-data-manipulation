# %% [markdown]
# # Creating random samples

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### Read CSV and set rating index sorted by labels

# %%
cereal = pd.read_csv("cereal.csv", index_col="name")
cereal.sort_index(inplace=True)
cereal
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Extracting one row at random

# %%
cereal.sample()
# Out:
#                mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Quaker Oatmeal   Q    H       100        5    2       0    2.7   -1.0      -1
#
#                 potass  vitamins  shelf  weight  cups     rating
# name
# Quaker Oatmeal     110         0      1     1.0  0.67  50.828392

# %%
cereal.sample()
# Out:
#               mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Fruitful Bran   K    C       120        3    0     240    5.0   14.0      12
#
#                potass  vitamins  shelf  weight  cups     rating
# name
# Fruitful Bran     190        25      3    1.33  0.67  41.015492

# %%
# remember this dataset doesn't conatin 80 cereals
cereal.sample(n = 40)
# Out:
#                             mfr type  calories  protein  fat  sodium  fiber  \
# name
# Wheat Chex                    R    C       100        3    1     230    3.0
# Special K                     K    C       110        6    0     230    1.0
# Grape-Nuts                    P    C       110        3    0     170    3.0
# Quaker Oat Squares            Q    C       100        4    1     135    2.0
# Maypo                         A    H       100        4    1       0    0.0
# Honey-comb                    P    C       110        1    0     180    0.0
# Cinnamon Toast Crunch         G    C       120        1    3     210    0.0
# Wheaties Honey Gold           G    C       110        2    1     200    1.0
# Puffed Wheat                  Q    C        50        2    0       0    1.0
# Crispy Wheat & Raisins        G    C       100        2    1     140    2.0
# Life                          Q    C       100        4    2     150    2.0
# ...

# %%
# so how about using a fraction instead like 50%
half_sample = cereal.sample(frac = .50)

# %%
half_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, Just Right Fruit & Nut to All-Bran
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       38 non-null     object
#  1   type      38 non-null     object
#  2   calories  38 non-null     int64
#  3   protein   38 non-null     int64
#  4   fat       38 non-null     int64
#  5   sodium    38 non-null     int64
#  6   fiber     38 non-null     float64
#  7   carbo     38 non-null     float64
#  8   sugars    38 non-null     int64
#  9   potass    38 non-null     int64
#  10  vitamins  38 non-null     int64
#  11  shelf     38 non-null     int64
#  12  weight    38 non-null     float64
#  13  cups      38 non-null     float64
#  14  rating    38 non-null     float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 4.8+ KB

# %%
half_sample
# Out:
#                                        mfr type  calories  protein  fat  \
# name
# Just Right Fruit & Nut                   K    C       140        3    1
# Trix                                     G    C       110        1    1
# Wheaties Honey Gold                      G    C       110        2    1
# Basic 4                                  G    C       130        3    2
# Total Whole Grain                        G    C       100        3    1
# Puffed Wheat                             Q    C        50        2    0
# Clusters                                 G    C       110        3    2
# Grape Nuts Flakes                        P    C       100        3    1
# Total Raisin Bran                        G    C       140        3    1
# Corn Chex                                R    C       110        2    0
# Frosted Flakes                           K    C       110        1    0
# Quaker Oat Squares                       Q    C       100        4    1
# ...

# %% [markdown]
# ### Select random columns

# %%
# random_columns = cereal.sample(n = 2, axis = 1)
radom_columns = cereal.sample(n = 2, axis = "columns")

# %%
random_columns
# Out:
#                            protein  cups
# name
# 100% Bran                        4  0.33
# 100% Natural Bran                3  1.00
# All-Bran                         4  0.33
# All-Bran with Extra Fiber        4  0.50
# Almond Delight                   2  0.75
# ...                            ...   ...
# Triples                          2  0.75
# Trix                             1  1.00
# Wheat Chex                       3  0.67
# Wheaties                         3  1.00
# Wheaties Honey Gold              2  0.75
#
# [77 rows x 2 columns]
