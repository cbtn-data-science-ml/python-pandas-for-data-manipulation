# %% [markdown]
# # Conditional Filtering

# %% [markdown]
# ### Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Employee data

# %%
df = pd.read_csv("employee.csv")

# %% [markdown]
# ### Head

# %%
# called the head method to see what were working with
df.head()
# Out:
#   first_name   last_name  salary  start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473    5/9/2020       NaN    True   management
# 1    Coretta      McEvon  637457   3/20/2020      Male   False  engineering
# 2   Clarette     Tarbett  977749  11/22/2020   Agender    True  engineering
# 3      Jaime  Gianneschi  253523    9/2/2020  Bigender   False    marketing
# 4      Ediva     Skelton  325185    2/4/2020    Female    True    marketing

# %% [markdown]
# ### Broadcasting Boolean Operations

# %%
df["team"]
# Out:
# 0          management
# 1         engineering
# 2         engineering
# 3           marketing
# 4           marketing
#             ...
# 995        management
# 996        management
# 997        management
# 998       engineering
# 999    data analytics
# Name: team, Length: 1000, dtype: object

# %%
# # broadcasting boolean operation: use == and not = ⚠️
df["team"] == "engineering"
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: team, Length: 1000, dtype: bool

# %%
# wrap df[] around the conditional operation to extract the values of the condition
df[df["team"] == "engineering"]
# Out:
#     first_name     last_name  salary  start_date      gender  remote  \
# 1      Coretta        McEvon  637457   3/20/2020        Male   False
# 2     Clarette       Tarbett  977749  11/22/2020     Agender    True
# 5      Auberta  Whistlecraft  510781         NaN  Polygender   False
# 6      Devland     Cominetti  194815   1/16/2021    Bigender   False
# 9      Susanna      Ivachyov  873134  11/19/2020     Agender   False
# ..         ...           ...     ...         ...         ...     ...
# 972    Kennett   Franzonello  580290    7/7/2020  Non-binary    True
# 973        Ola        Dautry  804650   8/20/2020     Agender    True
# 977      Theda        Sharpe  739171   5/29/2020    Bigender    True
# 988     Ariana   Culverhouse  901497   12/4/2020      Female   False
# 998     Jerald       Penella  862555    9/8/2020      Female   False
#
#             team
# 1    engineering
# 2    engineering
# 5    engineering
# 6    engineering
# 9    engineering
# ..           ...
# 972  engineering
# 973  engineering
# 977  engineering
# 988  engineering
# 998  engineering
#
# [230 rows x 7 columns]

# %%
# instead of wrapping df[] around the conditional operation, use a variable name
female_mask = df["gender"] == "Female"
df[female_mask]
# Out:
#     first_name    last_name  salary  start_date  gender  remote  \
# 4        Ediva      Skelton  325185    2/4/2020  Female    True
# 14      Alfred      Paraman  234494   1/19/2021  Female   False
# 46       Ernst   Fishbourne  994191  10/10/2020  Female    True
# 65       Ivory    MacMaster  848465   10/6/2020  Female   False
# 86      Ingmar       Cuesta  254625  10/29/2020  Female   False
# ..         ...          ...     ...         ...     ...     ...
# 983       Niki       Ivanin  132578  10/27/2020  Female   False
# 984     Carney        Blore  551939    5/6/2020  Female   False
# 988     Ariana  Culverhouse  901497   12/4/2020  Female   False
# 992        Roy     Axworthy  597997   8/25/2020  Female   False
# 998     Jerald      Penella  862555    9/8/2020  Female   False
#
#                team
# 4         marketing
# 14   data analytics
# 46   data analytics
# 65       management
# 86       management
# ..              ...
# 983       marketing
# 984      management
# 988     engineering
# 992       marketing
# 998     engineering
#
# [129 rows x 7 columns]

# %% [markdown]
# ### Filetring with One Condition

# %%
team_mask = df["team"] == "data analytics"
df[team_mask]
# Out:
#     first_name   last_name  salary start_date       gender  remote  \
# 7        Sarah     Feather  553617   4/5/2020          NaN    True
# 12        Dani  Withinshaw  152136  11/8/2020  Genderfluid    True
# 14      Alfred     Paraman  234494  1/19/2021       Female   False
# 28    Carmella       Pacht  599103   6/5/2020   Non-binary   False
# 29     Hershel    Bernasek  435872   9/4/2020     Bigender   False
# ..         ...         ...     ...        ...          ...     ...
# 987    Huntlee     Fortman  329453  9/25/2020     Bigender   False
# 991    Brandyn    Sprowles  654535   9/6/2020   Non-binary    True
# 993      Jenny  Ballentime  741738  5/20/2020     Bigender   False
# 994       Myra    Bidewell  908477   8/7/2020  Genderfluid   False
# 999     Aubrie        Hunt  549364  3/29/2020   Polygender   False
#
#                team
# 7    data analytics
# 12   data analytics
# 14   data analytics
# 28   data analytics
# 29   data analytics
# ..              ...
# 987  data analytics
# 991  data analytics
# 993  data analytics
# 994  data analytics
# 999  data analytics
#
# [269 rows x 7 columns]

# %%
team_mask = df["team"] != "data analytics"
df[team_mask]
# Out:
#     first_name   last_name  salary  start_date       gender  remote  \
# 0      Haleigh  Calderhead  334473    5/9/2020          NaN    True
# 1      Coretta      McEvon  637457   3/20/2020         Male   False
# 2     Clarette     Tarbett  977749  11/22/2020      Agender    True
# 3        Jaime  Gianneschi  253523    9/2/2020     Bigender   False
# 4        Ediva     Skelton  325185    2/4/2020       Female    True
# ..         ...         ...     ...         ...          ...     ...
# 992        Roy    Axworthy  597997   8/25/2020       Female   False
# 995     Ysabel  Stollmeyer  649625  10/18/2020   Polygender   False
# 996      Ashby  Threadgold  140806  12/28/2020  Genderfluid   False
# 997    Justino     Asquith  950280  10/26/2020  Genderqueer   False
# 998     Jerald     Penella  862555    9/8/2020       Female   False
#
#             team
# 0     management
# 1    engineering
# 2    engineering
# 3      marketing
# 4      marketing
# ..           ...
# 992    marketing
# 995   management
# 996   management
# 997   management
# 998  engineering
#
# [731 rows x 7 columns]

# %%
salary_mask = df["salary"] > 400000
df[salary_mask]
# Out:
#      first_name     last_name  salary  start_date       gender  remote  \
# 1       Coretta        McEvon  637457   3/20/2020         Male   False
# 2      Clarette       Tarbett  977749  11/22/2020      Agender    True
# 5       Auberta  Whistlecraft  510781         NaN   Polygender   False
# 7         Sarah       Feather  553617    4/5/2020          NaN    True
# 8    Andromache        McAviy  562931   9/15/2020   Non-binary    True
# ..          ...           ...     ...         ...          ...     ...
# 994        Myra      Bidewell  908477    8/7/2020  Genderfluid   False
# 995      Ysabel    Stollmeyer  649625  10/18/2020   Polygender   False
# 997     Justino       Asquith  950280  10/26/2020  Genderqueer   False
# 998      Jerald       Penella  862555    9/8/2020       Female   False
# 999      Aubrie          Hunt  549364   3/29/2020   Polygender   False
#
#                team
# 1       engineering
# 2       engineering
# 5       engineering
# 7    data analytics
# 8        management
# ..              ...
# 994  data analytics
# 995      management
# 997      management
# 998     engineering
# 999  data analytics
#
# [659 rows x 7 columns]

# %%
team_mask = df["start_date"] <= "2020-03-20"
df[team_mask]
# Out:
#     first_name    last_name  salary  start_date       gender  remote  \
# 2     Clarette      Tarbett  977749  11/22/2020      Agender    True
# 4        Ediva      Skelton  325185    2/4/2020       Female    True
# 6      Devland    Cominetti  194815   1/16/2021     Bigender   False
# 9      Susanna     Ivachyov  873134  11/19/2020      Agender   False
# 12        Dani   Withinshaw  152136   11/8/2020  Genderfluid    True
# ..         ...          ...     ...         ...          ...     ...
# 988     Ariana  Culverhouse  901497   12/4/2020       Female   False
# 989      Wilma      Raittie  382770  10/15/2020   Non-binary    True
# 995     Ysabel   Stollmeyer  649625  10/18/2020   Polygender   False
# 996      Ashby   Threadgold  140806  12/28/2020  Genderfluid   False
# 997    Justino      Asquith  950280  10/26/2020  Genderqueer   False
#
#                team
# 2       engineering
# 4         marketing
# 6       engineering
# 9       engineering
# 12   data analytics
# ..              ...
# 988     engineering
# 989       marketing
# 995      management
# 996      management
# 997      management
#
# [403 rows x 7 columns]

# %%
df[df["team"] == "engineering"]
# Out:
#     first_name     last_name  salary  start_date      gender  remote  \
# 1      Coretta        McEvon  637457   3/20/2020        Male   False
# 2     Clarette       Tarbett  977749  11/22/2020     Agender    True
# 5      Auberta  Whistlecraft  510781         NaN  Polygender   False
# 6      Devland     Cominetti  194815   1/16/2021    Bigender   False
# 9      Susanna      Ivachyov  873134  11/19/2020     Agender   False
# ..         ...           ...     ...         ...         ...     ...
# 972    Kennett   Franzonello  580290    7/7/2020  Non-binary    True
# 973        Ola        Dautry  804650   8/20/2020     Agender    True
# 977      Theda        Sharpe  739171   5/29/2020    Bigender    True
# 988     Ariana   Culverhouse  901497   12/4/2020      Female   False
# 998     Jerald       Penella  862555    9/8/2020      Female   False
#
#             team
# 1    engineering
# 2    engineering
# 5    engineering
# 6    engineering
# 9    engineering
# ..           ...
# 972  engineering
# 973  engineering
# 977  engineering
# 988  engineering
# 998  engineering
#
# [230 rows x 7 columns]

# %%
mask = df["team"] == "engineering"

# %%
df[mask]
# Out:
#     first_name     last_name  salary  start_date      gender  remote  \
# 1      Coretta        McEvon  637457   3/20/2020        Male   False
# 2     Clarette       Tarbett  977749  11/22/2020     Agender    True
# 5      Auberta  Whistlecraft  510781         NaN  Polygender   False
# 6      Devland     Cominetti  194815   1/16/2021    Bigender   False
# 9      Susanna      Ivachyov  873134  11/19/2020     Agender   False
# ..         ...           ...     ...         ...         ...     ...
# 972    Kennett   Franzonello  580290    7/7/2020  Non-binary    True
# 973        Ola        Dautry  804650   8/20/2020     Agender    True
# 977      Theda        Sharpe  739171   5/29/2020    Bigender    True
# 988     Ariana   Culverhouse  901497   12/4/2020      Female   False
# 998     Jerald       Penella  862555    9/8/2020      Female   False
#
#             team
# 1    engineering
# 2    engineering
# 5    engineering
# 6    engineering
# 9    engineering
# ..           ...
# 972  engineering
# 973  engineering
# 977  engineering
# 988  engineering
# 998  engineering
#
# [230 rows x 7 columns]

# %%
mask_2 = df["team"] != "marketing"

# %%
df[mask_2]
# Out:
#     first_name     last_name  salary  start_date       gender  remote  \
# 0      Haleigh    Calderhead  334473    5/9/2020          NaN    True
# 1      Coretta        McEvon  637457   3/20/2020         Male   False
# 2     Clarette       Tarbett  977749  11/22/2020      Agender    True
# 5      Auberta  Whistlecraft  510781         NaN   Polygender   False
# 6      Devland     Cominetti  194815   1/16/2021     Bigender   False
# ..         ...           ...     ...         ...          ...     ...
# 995     Ysabel    Stollmeyer  649625  10/18/2020   Polygender   False
# 996      Ashby    Threadgold  140806  12/28/2020  Genderfluid   False
# 997    Justino       Asquith  950280  10/26/2020  Genderqueer   False
# 998     Jerald       Penella  862555    9/8/2020       Female   False
# 999     Aubrie          Hunt  549364   3/29/2020   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 5       engineering
# 6       engineering
# ..              ...
# 995      management
# 996      management
# 997      management
# 998     engineering
# 999  data analytics
#
# [740 rows x 7 columns]

# %%
mask_3 = df["salary"] > 995000

# %%
df[mask_3]
# Out:
#     first_name    last_name  salary  start_date      gender  remote  \
# 191      Terry        Rives  995927  11/14/2020  Non-binary    True
# 205       Cati  Hendrickson  997426    5/6/2020  Non-binary   False
# 240     Juieta      Alyutin  995710   7/14/2020  Non-binary   False
#
#                team
# 191  data analytics
# 205       marketing
# 240  data analytics
