# %% [markdown]
# # Find duplicates with `.duplicated()`

# %% [markdown]
# ### Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Read CSV

# %%
# read csv and parse the data column
df = pd.read_csv("employee.csv", parse_dates = ["start_date"])
df.head()
# Out:
#   first_name   last_name  salary start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473 2020-05-09       NaN    True   management
# 1    Coretta      McEvon  637457 2020-03-20      Male   False  engineering
# 2   Clarette     Tarbett  977749 2020-11-22   Agender    True  engineering
# 3      Jaime  Gianneschi  253523 2020-09-02  Bigender   False    marketing
# 4      Ediva     Skelton  325185 2020-02-04    Female    True    marketing

# %%
# sort values by first_name
df.sort_values("first_name", inplace=True)
df.head()
# Out:
#     first_name last_name  salary start_date      gender  remote  \
# 872      Aaron   Caddens  583629 2020-10-05      Female    True
# 619      Aaron     Pohls  188614 2021-01-29        Male    True
# 74        Abbi      Waby  433227 2020-04-13  Polygender    True
# 535       Abby    August  280480 2020-08-10  Polygender    True
# 898    Adaline   Cohalan  260075 2020-07-30  Polygender    True
#
#                team
# 872       marketing
# 619       marketing
# 74        marketing
# 535  data analytics
# 898     engineering

# %%
df["first_name"]
# Out:
# 872      Aaron
# 619      Aaron
# 74        Abbi
# 535       Abby
# 898    Adaline
#         ...
# 550    Zachary
# 540       Zara
# 675    Zebulon
# 783       Zita
# 476       Zita
# Name: first_name, Length: 1000, dtype: object

# %%
df["first_name"].duplicated()
# Out:
# 872    False
# 619     True
# 74     False
# 535    False
# 898    False
#        ...
# 550    False
# 540    False
# 675    False
# 783    False
# 476     True
# Name: first_name, Length: 1000, dtype: bool

# %%
# by default does not return first duplicate instance
df[df["first_name"].duplicated()]
# Out:
#      first_name     last_name  salary start_date       gender  remote  \
# 619       Aaron         Pohls  188614 2021-01-29         Male    True
# 83     Adrianne        Charte  573994 2020-07-13         Male    True
# 850      Aluino        Reyner  419740 2020-06-07   Polygender   False
# 988      Ariana   Culverhouse  901497 2020-12-04       Female   False
# 751        Arin       Pealing  190653 2020-12-01     Bigender    True
# 822   Augustine      Yukhnini  374683 2020-05-22   Non-binary    True
# 811      Bernie          Asty  864231 2020-04-25  Genderfluid    True
# 163     Bethany       Carthew  612868 2020-02-25       Female    True
# 61        Bevon        Chaman  183298 2020-06-29  Genderfluid   False
# 456      Blithe           Gay  338102 2020-02-09         Male    True
# 213     Brandea       Lyenyng  443060 2020-11-18  Genderqueer   False
# 76       Briggs     Maplesden  736681 2020-03-29  Genderqueer    True
# 121       Brody    Grzeszczyk  391408 2020-10-18         Male    True
# 976       Bruis       Hazzard  818218 2020-07-28       Female   False
# 78     Chrystel       Goligly  953316 2020-10-12  Genderfluid    True
# 868    Clarinda        Upsale  765038 2020-05-11       Female    True
# 692    Clarinda        Dienes  273996 2020-06-03  Genderfluid    True
# 73      Corrina      Chaloner  330510        NaT         Male   False
# 464       Datha      Kennealy  795372 2020-08-15   Non-binary    True
# 807       Dedra          Gegg  248043 2020-03-27   Polygender   False
# 914       Drona        Allone  580355 2020-02-17       Female   False
# 590        Egan    Kenderdine  550391 2020-06-29  Genderqueer    True
# 716        Esme      Gockeler  543483 2020-08-03  Genderqueer   False
# 82         Esra         Nacci  595367 2020-05-31   Polygender    True
# 479       Gayle       Peirson  292239 2020-10-29  Genderfluid   False
# 825     Glenden        Camois  871529        NaT     Bigender    True
# 791      Graham        Ferran  418425 2020-10-25   Non-binary   False
# 947        Gray       Whitley  702445 2020-07-08  Genderfluid    True
# 465    Hurleigh       Stedall  699627 2020-07-28         Male    True
# 129       Hyman           Bye  758704 2020-10-29          NaN   False
# 998      Jerald       Penella  862555 2020-09-08       Female   False
# 669    Joycelin         Oaten  529059 2020-11-14       Female    True
# 340        Joye        Evetts  241063 2020-06-29   Non-binary   False
# 694       Julee     Dranfield  703265 2020-05-15      Agender    True
# 283     Kikelia         Dunne  389606 2020-12-11      Agender   False
# 588       Levon     Manderson  969075 2020-12-04      Agender   False
# 119        Mike  Sommerscales  264558 2020-12-26          NaN   False
# 543        Myer      Gatherer  531530 2020-05-08      Agender   False
# 873      Nellie    MacCaughey  939492 2020-07-29         Male    True
# 509      Nickie        Scully  534675 2020-12-11   Polygender   False
# 806       Orson     MacDougal  270566 2020-05-10       Female   False
# 962     Othelia       Harling  867761 2020-10-13      Agender   False
# 503    Pembroke      Greenmon  353573 2020-05-23      Agender    True
# 108       Randa      Tweedell  941519 2020-11-13   Non-binary    True
# 982       Reeta         Nurse  447882 2020-08-20         Male    True
# 217       Ronny      Gaisford  939459 2020-09-08   Polygender    True
# 639         Sax        Denzey  685191 2020-06-29         Male   False
# 495      Shaine      Janssens  954319 2020-08-27  Genderfluid    True
# 956  Sutherland      Loadwick  120513 2020-02-12   Polygender   False
# 115      Sylvan     Thorneley  697506 2020-07-19         Male   False
# 491     Tamqrah       MacCard  893986 2020-07-07       Female   False
# 319       Towny      Tippings  662192 2020-10-07       Female    True
# 307      Tressa        Pobjoy  611694 2020-08-22         Male   False
# 841      Wandie       Jozwiak  144740 2020-05-02         Male    True
# 92      Whitney     O' Dooley  578414 2020-06-25     Bigender   False
# 630       Wilma        Jewess  263290 2020-06-27  Genderqueer    True
# 989       Wilma       Raittie  382770 2020-10-15   Non-binary    True
# 118       Winny         Hache  260980 2020-05-06         Male   False
# 476        Zita       Bewicke  198218 2020-12-11       Female    True
#
#                team
# 619       marketing
# 83       management
# 850      management
# 988     engineering
# 751  data analytics
# 822       marketing
# 811       marketing
# 163  data analytics
# 61       management
# 456       marketing
# 213      management
# 76        marketing
# 121       marketing
# 976      management
# 78   data analytics
# 868     engineering
# 692      management
# 73        marketing
# 464      management
# 807       marketing
# 914     engineering
# 590      management
# 716     engineering
# 82      engineering
# 479  data analytics
# 825  data analytics
# 791       marketing
# 947      management
# 465       marketing
# 129  data analytics
# 998     engineering
# 669  data analytics
# 340     engineering
# 694  data analytics
# 283  data analytics
# 588     engineering
# 119      management
# 543  data analytics
# 873     engineering
# 509  data analytics
# 806     engineering
# 962       marketing
# 503      management
# 108  data analytics
# 982  data analytics
# 217      management
# 639       marketing
# 495  data analytics
# 956     engineering
# 115     engineering
# 491     engineering
# 319  data analytics
# 307     engineering
# 841      management
# 92   data analytics
# 630     engineering
# 989       marketing
# 118      management
# 476  data analytics

# %%
# keep= "first" | "last" | False
all_dupes = df["first_name"].duplicated(keep=False)

# %%
df[all_dupes]
# Out:
#      first_name   last_name  salary start_date       gender  remote  \
# 956  Sutherland    Loadwick  120513 2020-02-12   Polygender   False
# 665      Sylvan     Humfrey  947719 2020-08-10         Male    True
# 115      Sylvan   Thorneley  697506 2020-07-19         Male   False
# 556     Tamqrah      Levick  294374 2020-06-24     Bigender   False
# 491     Tamqrah     MacCard  893986 2020-07-07       Female   False
# 406       Towny      Roback  932998 2020-10-05       Female   False
# 319       Towny    Tippings  662192 2020-10-07       Female    True
# 229      Tressa        Ixer  625357 2020-10-14       Female    True
# 307      Tressa      Pobjoy  611694 2020-08-22         Male   False
# 304      Wandie  Elverstone  355554 2021-01-28       Female   False
# 841      Wandie     Jozwiak  144740 2020-05-02         Male    True
# 110     Whitney       Furze  793725 2020-10-14     Bigender   False
# 92      Whitney   O' Dooley  578414 2020-06-25     Bigender   False
# 659       Wilma       Ibell  601155 2020-10-15   Non-binary   False
# 630       Wilma      Jewess  263290 2020-06-27  Genderqueer    True
# 989       Wilma     Raittie  382770 2020-10-15   Non-binary    True
# 257       Winny   Antonutti  123855 2020-07-07   Non-binary   False
# 118       Winny       Hache  260980 2020-05-06         Male   False
# 783        Zita      Follos  891648 2020-10-09  Genderqueer   False
# 476        Zita     Bewicke  198218 2020-12-11       Female    True
#
#                team
# 956     engineering
# 665     engineering
# 115     engineering
# 556      management
# 491     engineering
# 406       marketing
# 319  data analytics
# 229     engineering
# 307     engineering
# 304       marketing
# 841      management
# 110      management
# 92   data analytics
# 659       marketing
# 630     engineering
# 989       marketing
# 257       marketing
# 118      management
# 783       marketing
# 476  data analytics

# %%
df[all_dupes].tail(20)
# Out:
#      first_name   last_name  salary start_date       gender  remote  \
# 956  Sutherland    Loadwick  120513 2020-02-12   Polygender   False
# 665      Sylvan     Humfrey  947719 2020-08-10         Male    True
# 115      Sylvan   Thorneley  697506 2020-07-19         Male   False
# 556     Tamqrah      Levick  294374 2020-06-24     Bigender   False
# 491     Tamqrah     MacCard  893986 2020-07-07       Female   False
# 406       Towny      Roback  932998 2020-10-05       Female   False
# 319       Towny    Tippings  662192 2020-10-07       Female    True
# 229      Tressa        Ixer  625357 2020-10-14       Female    True
# 307      Tressa      Pobjoy  611694 2020-08-22         Male   False
# 304      Wandie  Elverstone  355554 2021-01-28       Female   False
# 841      Wandie     Jozwiak  144740 2020-05-02         Male    True
# 110     Whitney       Furze  793725 2020-10-14     Bigender   False
# 92      Whitney   O' Dooley  578414 2020-06-25     Bigender   False
# 659       Wilma       Ibell  601155 2020-10-15   Non-binary   False
# 630       Wilma      Jewess  263290 2020-06-27  Genderqueer    True
# 989       Wilma     Raittie  382770 2020-10-15   Non-binary    True
# 257       Winny   Antonutti  123855 2020-07-07   Non-binary   False
# 118       Winny       Hache  260980 2020-05-06         Male   False
# 783        Zita      Follos  891648 2020-10-09  Genderqueer   False
# 476        Zita     Bewicke  198218 2020-12-11       Female    True
#
#                team
# 956     engineering
# 665     engineering
# 115     engineering
# 556      management
# 491     engineering
# 406       marketing
# 319  data analytics
# 229     engineering
# 307     engineering
# 304       marketing
# 841      management
# 110      management
# 92   data analytics
# 659       marketing
# 630     engineering
# 989       marketing
# 257       marketing
# 118      management
# 783       marketing
# 476  data analytics

# %%
# reverse values with ~  tilde
mask_dupes = ~df["first_name"].duplicated(keep=False)

# %%
mask_dupes
# Out:
# 872    False
# 619    False
# 74      True
# 535     True
# 898     True
#        ...
# 550     True
# 540     True
# 675     True
# 783    False
# 476    False
# Name: first_name, Length: 1000, dtype: bool

# %%
# returns unique values 🎉
df[mask_dupes]
# Out:
#     first_name    last_name  salary start_date       gender  remote  \
# 74        Abbi         Waby  433227 2020-04-13   Polygender    True
# 535       Abby       August  280480 2020-08-10   Polygender    True
# 898    Adaline      Cohalan  260075 2020-07-30   Polygender    True
# 47       Adara        Wakes  727063 2020-05-04  Genderfluid   False
# 851      Adham     Bennough  907358 2020-06-24  Genderfluid    True
# ..         ...          ...     ...        ...          ...     ...
# 995     Ysabel   Stollmeyer  649625 2020-10-18   Polygender   False
# 586     Yvette  Vasilischev  300495 2020-03-24  Genderfluid    True
# 550    Zachary       Herity  925381 2020-10-23   Non-binary   False
# 540       Zara       Carbin  848862 2021-01-26   Non-binary    True
# 675    Zebulon     Lattimer  933655 2020-07-25         Male    True
#
#                team
# 74        marketing
# 535  data analytics
# 898     engineering
# 47       management
# 851  data analytics
# ..              ...
# 995      management
# 586      management
# 550  data analytics
# 540  data analytics
# 675     engineering
#
# [884 rows x 7 columns]
