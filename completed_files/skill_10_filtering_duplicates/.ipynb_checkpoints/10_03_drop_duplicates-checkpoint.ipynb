# %% [markdown]
# # Drop Duplicates

# %% [markdown]
# ### Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Employee data

# %%
df = pd.read_csv("employee.csv", parse_dates = ["start_date"])

# %% [markdown]
# ### Head

# %%
# called the head method to see what were working with
df.head()
# Out:
#   first_name   last_name  salary start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473 2020-05-09       NaN    True   management
# 1    Coretta      McEvon  637457 2020-03-20      Male   False  engineering
# 2   Clarette     Tarbett  977749 2020-11-22   Agender    True  engineering
# 3      Jaime  Gianneschi  253523 2020-09-02  Bigender   False    marketing
# 4      Ediva     Skelton  325185 2020-02-04    Female    True    marketing

# %%
len(df)
# Out:
# 1000

# %%
# all values must be duplicates to be dropped
len(df.drop_duplicates())
# Out:
# 1000

# %%
# keeps the first duplicate instance and drops the rest
len(df.drop_duplicates(subset = ["first_name"], keep="first"))
# Out:
# 941

# %%
df.drop_duplicates(subset = ["first_name"], keep="first")
# Out:
#     first_name   last_name  salary start_date       gender  remote  \
# 0      Haleigh  Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta      McEvon  637457 2020-03-20         Male   False
# 2     Clarette     Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime  Gianneschi  253523 2020-09-02     Bigender   False
# 4        Ediva     Skelton  325185 2020-02-04       Female    True
# ..         ...         ...     ...        ...          ...     ...
# 994       Myra    Bidewell  908477 2020-08-07  Genderfluid   False
# 995     Ysabel  Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby  Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino     Asquith  950280 2020-10-26  Genderqueer   False
# 999     Aubrie        Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# ..              ...
# ...

# %%
len(df.drop_duplicates(subset = ["first_name"], keep="last"))
# Out:
# 941

# %%
df.drop_duplicates(subset = ["first_name"], keep="last")
# Out:
#     first_name   last_name  salary start_date       gender  remote  \
# 0      Haleigh  Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta      McEvon  637457 2020-03-20         Male   False
# 2     Clarette     Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime  Gianneschi  253523 2020-09-02     Bigender   False
# 4        Ediva     Skelton  325185 2020-02-04       Female    True
# ..         ...         ...     ...        ...          ...     ...
# 995     Ysabel  Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby  Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino     Asquith  950280 2020-10-26  Genderqueer   False
# 998     Jerald     Penella  862555 2020-09-08       Female   False
# 999     Aubrie        Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# ..              ...
# ...

# %%
# counts all dropped dupliactes
len(df.drop_duplicates(subset = ["first_name"], keep=False))
# Out:
# 884

# %%
# drops all dupliactes 
df.drop_duplicates(subset = ["first_name"], keep=False)
# Out:
#     first_name   last_name  salary start_date       gender  remote  \
# 0      Haleigh  Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta      McEvon  637457 2020-03-20         Male   False
# 2     Clarette     Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime  Gianneschi  253523 2020-09-02     Bigender   False
# 4        Ediva     Skelton  325185 2020-02-04       Female    True
# ..         ...         ...     ...        ...          ...     ...
# 994       Myra    Bidewell  908477 2020-08-07  Genderfluid   False
# 995     Ysabel  Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby  Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino     Asquith  950280 2020-10-26  Genderqueer   False
# 999     Aubrie        Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# ..              ...
# ...

# %%
# see all deleted occurrences in two columns and make permanent
df.drop_duplicates(subset = ["first_name", "team"], inplace=True)

# %%
df
# Out:
#     first_name   last_name  salary start_date       gender  remote  \
# 0      Haleigh  Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta      McEvon  637457 2020-03-20         Male   False
# 2     Clarette     Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime  Gianneschi  253523 2020-09-02     Bigender   False
# 4        Ediva     Skelton  325185 2020-02-04       Female    True
# ..         ...         ...     ...        ...          ...     ...
# 994       Myra    Bidewell  908477 2020-08-07  Genderfluid   False
# 995     Ysabel  Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby  Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino     Asquith  950280 2020-10-26  Genderqueer   False
# 999     Aubrie        Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# ..              ...
# ...
