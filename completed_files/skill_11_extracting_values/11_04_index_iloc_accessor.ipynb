# %% [markdown]
# # Return rows by index positions with `.iloc[ ]`

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### Read CSV
# We'll continue with the 80 Cereals dataset and this time we'll keep the numeric index and not use the name lable, like we did with `.loc[ ] `.

# %%
cereal = pd.read_csv("cereal.csv")
cereal
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Indexing with `iloc[ ]`

# %%
# sytax is much like .loc[ ], here we have the first row
cereal.iloc[0]
# Out:
# name        100% Bran
# mfr                 N
# type                C
# calories           70
# protein             4
# fat                 1
# sodium            130
# fiber            10.0
# carbo             5.0
# sugars              6
# potass            280
# vitamins           25
# shelf               3
# weight            1.0
# cups             0.33
# rating      68.402973
# Name: 0, dtype: object

# %%
# here we ahve the last row using the negative index position of -1
cereal.iloc[-1]
# Out:
# name        Wheaties Honey Gold
# mfr                           G
# type                          C
# calories                    110
# protein                       2
# fat                           1
# sodium                      200
# fiber                       1.0
# carbo                      16.0
# sugars                        8
# potass                       60
# vitamins                     25
# shelf                         1
# weight                      1.0
# cups                       0.75
# rating                36.187559
# Name: 76, dtype: object

# %% [markdown]
# ### Slicing with `.iloc[ ]`

# %%
# iloc[] is not inclusive, so keep that in mind!
cereal.iloc[0:4]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912

# %%
# you can also slice like this
cereal.iloc[1:]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal.iloc[::2]
# Out:
#                                 name mfr type  calories  protein  fat  sodium  \
# 0                          100% Bran   N    C        70        4    1     130
# 2                           All-Bran   K    C        70        4    1     260
# 4                     Almond Delight   R    C       110        2    2     200
# 6                        Apple Jacks   K    C       110        2    0     125
# 8                          Bran Chex   R    C        90        2    1     200
# 10                      Cap'n'Crunch   Q    C       120        1    2     220
# 12             Cinnamon Toast Crunch   G    C       120        1    3     210
# 14                       Cocoa Puffs   G    C       110        1    1     180
# 16                       Corn Flakes   K    C       100        2    0     290
# 18                     Count Chocula   G    C       110        1    1     180
# 20            Cream of Wheat (Quick)   N    H       100        3    0      80
# ...

# %% [markdown]
# ### Return multiple rows by index

# %%
cereal.iloc[[0,34,76]]
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 0             100% Bran   N    C        70        4    1     130   10.0
# 34   Great Grains Pecan   P    C       120        3    3      75    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 34   13.0       4     100        25      3     1.0  0.33  45.811716
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %%
# this dataset only contains 77 cereals, not 80, so beware
cereal.iloc[[0, 10, 80]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    1481         try:
# -> 1482             return self.obj._take_with_is_copy(key, axis=axis)
#    1483         except IndexError as err:
#
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3727         """
# -> 3728         result = self.take(indices=indices, axis=axis)
#    3729         # Maybe set copy if we didn't actually change the index.
#
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3714
# -> 3715         new_data = self._mgr.take(
#    3716             indices, axis=self._get_block_manager_axis(axis), verify=True
#
# ...

# %% [markdown]
# ### Returning multiple indexes

# %%
cereal.iloc[[2, 66, 72]]
# Out:
#         name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 2   All-Bran   K    C        70        4    1     260    9.0    7.0       5
# 66    Smacks   K    C       110        2    1      70    1.0    9.0      15
# 72   Triples   G    C       110        2    1     250    0.0   21.0       3
#
#     potass  vitamins  shelf  weight  cups     rating
# 2      320        25      3     1.0  0.33  59.425505
# 66      40        25      2     1.0  0.75  31.230054
# 72      60        25      3     1.0  0.75  39.106174

# %%
# order matters
cereal.iloc[[66, 72, 2]]
# Out:
#         name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 66    Smacks   K    C       110        2    1      70    1.0    9.0      15
# 72   Triples   G    C       110        2    1     250    0.0   21.0       3
# 2   All-Bran   K    C        70        4    1     260    9.0    7.0       5
#
#     potass  vitamins  shelf  weight  cups     rating
# 66      40        25      2     1.0  0.75  31.230054
# 72      60        25      3     1.0  0.75  39.106174
# 2      320        25      3     1.0  0.33  59.425505

# %% [markdown]
# ### Return specific columns for an index label

# %%
cereal.iloc[66, [0, 3, 9]]
# Out:
# name        Smacks
# calories       110
# sugars          15
# Name: 66, dtype: object

# %%
# you can also return mulpitle rows with specific columns
cereal.iloc[[66, 72], [0, 3, 9]]
# Out:
#        name  calories  sugars
# 66   Smacks       110      15
# 72  Triples       110       3

# %% [markdown]
# ### You can also leverage slicing!

# %%
cereal.iloc[2:72, [0, 3, 9]]
# Out:
#                          name  calories  sugars
# 2                    All-Bran        70       5
# 3   All-Bran with Extra Fiber        50       0
# 4              Almond Delight       110       8
# 5     Apple Cinnamon Cheerios       110      10
# 6                 Apple Jacks       110      14
# ..                        ...       ...     ...
# 67                  Special K       110       3
# 68    Strawberry Fruit Wheats        90       5
# 69          Total Corn Flakes       110       3
# 70          Total Raisin Bran       140      14
# 71          Total Whole Grain       100       3
#
# [70 rows x 3 columns]

# %%
cereal.iloc[2:72:2, 0:9]
# Out:
#                                 name mfr type  calories  protein  fat  sodium  \
# 2                           All-Bran   K    C        70        4    1     260
# 4                     Almond Delight   R    C       110        2    2     200
# 6                        Apple Jacks   K    C       110        2    0     125
# 8                          Bran Chex   R    C        90        2    1     200
# 10                      Cap'n'Crunch   Q    C       120        1    2     220
# 12             Cinnamon Toast Crunch   G    C       120        1    3     210
# 14                       Cocoa Puffs   G    C       110        1    1     180
# 16                       Corn Flakes   K    C       100        2    0     290
# 18                     Count Chocula   G    C       110        1    1     180
# 20            Cream of Wheat (Quick)   N    H       100        3    0      80
# 22            Crispy Wheat & Raisins   G    C       100        2    1     140
# ...

# %%
# what is this?
cereal.iloc[::, ::]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...
