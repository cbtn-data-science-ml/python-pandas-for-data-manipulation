# %% [markdown]
# # Return rows by index lables with `.loc[ ]`

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### Read CSV
# In this set of videos we'll use the [80 cereals dataset](https://www.kaggle.com/crawford/80-cereals) from Kaggle which is also avaiable in the course GitHub repo here: [80 cereals dataset](https://github.com/cbtn-data-science-ml/python-pandas-for-data-manipulation/tree/main/datasets). I've icluded the Kaggle link so you can learn more about the dataset, but they're the same, so feel free to use either resourse.
#
# We'll also use the name as the index by using the `index_col` parameter inside of the `.read_csv()` method.

# %%
cereal = pd.read_csv("cereal.csv", index_col="name")
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %% [markdown]
# ### Optimize dataset with sorting
# It's  a best practice to sort the index to help pandas be more efficient when looking for values.

# %%
cereal.sort_index(inplace=True)
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %% [markdown]
# ### Access rows by index lables with `.loc[ ]`

# %%
cereal.loc["Almond Delight"]
# Out:
# mfr                 R
# type                C
# calories          110
# protein             2
# fat                 2
# sodium            200
# fiber             1.0
# carbo            14.0
# sugars              8
# potass             -1
# vitamins           25
# shelf               3
# weight            1.0
# cups             0.75
# rating      34.384843
# Name: Almond Delight, dtype: object

# %%
cereal.loc["All-Bran"]
# Out:
# mfr                 K
# type                C
# calories           70
# protein             4
# fat                 1
# sodium            260
# fiber             9.0
# carbo             7.0
# sugars              5
# potass            320
# vitamins           25
# shelf               3
# weight            1.0
# cups             0.33
# rating      59.425505
# Name: All-Bran, dtype: object

# %%
# if you misspell a lable, you'll get a KeyError since it doesn't exist
cereal.loc["All-Brand"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'All-Brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/p3/mqhw42ws2pdb_zc2w00cp34m0000gn/T/ipykernel_37245/3197790996.py in <module>
#       1 # if you misspell a lable, you'll get a KeyError since it doesn't exist
# ----> 2 cereal.loc["All-Brand"]
#
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1200         # fall thru to straight lookup
#    1201         self._validate_key(key, axis)
# -> 1202         return self._get_label(key, axis=axis)
#    1203
#    1204     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1151     def _get_label(self, label, axis: int):
#    1152         # GH#5667 this will fail if the label is not present in the axis.
# -> 1153         return self.obj.xs(label, axis=axis)
#    1154
#    1155     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3874                     new_index = index[loc]
#    3875         else:
# -> 3876             loc = index.get_loc(key)
#    3877
#    3878             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/envs/cbtn_pandas/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'All-Brand'

# %% [markdown]
# ### Slicing with `.loc[ ]`

# %%
# label slicing is inclusive 
cereal.loc["100% Bran":"All-Bran"]
# Out:
#                   mfr type  calories  protein  fat  sodium  fiber  carbo  \
# name
# 100% Bran           N    C        70        4    1     130   10.0    5.0
# 100% Natural Bran   Q    C       120        3    5      15    2.0    8.0
# All-Bran            K    C        70        4    1     260    9.0    7.0
#
#                    sugars  potass  vitamins  shelf  weight  cups     rating
# name
# 100% Bran               6     280        25      3     1.0  0.33  68.402973
# 100% Natural Bran       8     135         0      3     1.0  1.00  33.983679
# All-Bran                5     320        25      3     1.0  0.33  59.425505

# %%
cereal.tail()
# Out:
#                     mfr type  calories  protein  fat  sodium  fiber  carbo  \
# name
# Triples               G    C       110        2    1     250    0.0   21.0
# Trix                  G    C       110        1    1     140    0.0   13.0
# Wheat Chex            R    C       100        3    1     230    3.0   17.0
# Wheaties              G    C       100        3    1     200    3.0   17.0
# Wheaties Honey Gold   G    C       110        2    1     200    1.0   16.0
#
#                      sugars  potass  vitamins  shelf  weight  cups     rating
# name
# Triples                   3      60        25      3     1.0  0.75  39.106174
# Trix                     12      25        25      2     1.0  1.00  27.753301
# Wheat Chex                3     115        25      1     1.0  0.67  49.787445
# Wheaties                  3     110        25      1     1.0  1.00  51.592193
# Wheaties Honey Gold       8      60        25      1     1.0  0.75  36.187559

# %%
# you can return every other ceral using steps of 2
cereal.loc["100% Bran":"Wheaties Honey Gold":2]
# Out:
#                                  mfr type  calories  protein  fat  sodium  \
# name
# 100% Bran                          N    C        70        4    1     130
# All-Bran                           K    C        70        4    1     260
# Almond Delight                     R    C       110        2    2     200
# Apple Jacks                        K    C       110        2    0     125
# Bran Chex                          R    C        90        2    1     200
# Cap'n'Crunch                       Q    C       120        1    2     220
# Cinnamon Toast Crunch              G    C       120        1    3     210
# Cocoa Puffs                        G    C       110        1    1     180
# Corn Flakes                        K    C       100        2    0     290
# Count Chocula                      G    C       110        1    1     180
# Cream of Wheat (Quick)             N    H       100        3    0      80
# Crispy Wheat & Raisins             G    C       100        2    1     140
# Froot Loops                        K    C       110        2    1     125
# Frosted Mini-Wheats                K    C       100        3    0       0
# Fruitful Bran                      K    C       120        3    0     240
# Golden Crisp                       P    C       100        2    0      45
# Grape Nuts Flakes                  P    C       100        3    1     140
# Great Grains Pecan                 P    C       120        3    3      75
# Honey Nut Cheerios                 G    C       110        3    1     250
# Just Right Crunchy  Nuggets        K    C       110        2    1     170
# Kix                                G    C       110        2    1     260
# Lucky Charms                       G    C       110        2    1     180
# Muesli Raisins; Dates; & Almonds   R    C       150        4    3      95
# Mueslix Crispy Blend               K    C       160        3    2     150
# Nut&Honey Crunch                   K    C       120        2    1     190
# Nutri-grain Wheat                  K    C        90        3    0     170
# Post Nat. Raisin Bran              P    C       120        3    1     200
# Puffed Rice                        Q    C        50        1    0       0
# Quaker Oat Squares                 Q    C       100        4    1     135
# Raisin Bran                        K    C       120        3    1     210
# Raisin Squares                     K    C        90        2    0       0
# Rice Krispies                      K    C       110        2    0     290
# Shredded Wheat 'n'Bran             N    C        90        3    0       0
# Smacks                             K    C       110        2    1      70
# All-Bran     320        25      3     1.0  0.33  59.425505

# %% [markdown]
# ### Return specific columns for an index label

# %%
cereal.loc["Smacks", ["calories", "sugars"]]
# Out:
# calories    110
# sugars       15
# Name: Smacks, dtype: object

# %%
# you can also return mulpitle rows with specific columns
cereal.loc[["Smacks", "Triples"], ["calories", "sugars"]]
# Out:
#          calories  sugars
# name
# Smacks        110      15
# Triples       110       3

# %% [markdown]
# ### You can also leverage slicing!

# %%
cereal.loc["All-Bran":"Triples", ["calories", "sugars"]]
# Out:
#                            calories  sugars
# name
# All-Bran                         70       5
# All-Bran with Extra Fiber        50       0
# Almond Delight                  110       8
# Apple Cinnamon Cheerios         110      10
# Apple Jacks                     110      14
# ...                             ...     ...
# Strawberry Fruit Wheats          90       5
# Total Corn Flakes               110       3
# Total Raisin Bran               140      14
# Total Whole Grain               100       3
# Triples                         110       3
#
# [71 rows x 2 columns]

# %%
cereal.loc["All-Bran":"Triples":2, "calories":"sugars"]
# Out:
#                                   calories  protein  fat  sodium  fiber  \
# name
# All-Bran                                70        4    1     260    9.0
# Almond Delight                         110        2    2     200    1.0
# Apple Jacks                            110        2    0     125    1.0
# Bran Chex                               90        2    1     200    4.0
# Cap'n'Crunch                           120        1    2     220    0.0
# Cinnamon Toast Crunch                  120        1    3     210    0.0
# Cocoa Puffs                            110        1    1     180    0.0
# Corn Flakes                            100        2    0     290    1.0
# Count Chocula                          110        1    1     180    0.0
# Cream of Wheat (Quick)                 100        3    0      80    1.0
# Crispy Wheat & Raisins                 100        2    1     140    2.0
# Froot Loops                            110        2    1     125    1.0
# Frosted Mini-Wheats                    100        3    0       0    3.0
# Fruitful Bran                          120        3    0     240    5.0
# Golden Crisp                           100        2    0      45    0.0
# Grape Nuts Flakes                      100        3    1     140    3.0
# Great Grains Pecan                     120        3    3      75    3.0
# Honey Nut Cheerios                     110        3    1     250    1.5
# Just Right Crunchy  Nuggets            110        2    1     170    1.0
# Kix                                    110        2    1     260    0.0
# Lucky Charms                           110        2    1     180    0.0
# Muesli Raisins; Dates; & Almonds       150        4    3      95    3.0
# Mueslix Crispy Blend                   160        3    2     150    3.0
# Nut&Honey Crunch                       120        2    1     190    0.0
# Nutri-grain Wheat                       90        3    0     170    3.0
# Post Nat. Raisin Bran                  120        3    1     200    6.0
# Puffed Rice                             50        1    0       0    0.0
# Quaker Oat Squares                     100        4    1     135    2.0
# Raisin Bran                            120        3    1     210    5.0
# Raisin Squares                          90        2    0       0    2.0
# Rice Krispies                          110        2    0     290    0.0
# Shredded Wheat 'n'Bran                  90        3    0       0    4.0
# Smacks                                 110        2    1      70    1.0
# Strawberry Fruit Wheats                 90        2    0      15    3.0
# Total Raisin Bran                      140        3    1     190    4.0
# Triples                                110        2    1     250    0.0
#
#                                   carbo  sugars
# name
# All-Bran                            7.0       5
# Almond Delight                     14.0       8
# Apple Jacks                        11.0      14
# Bran Chex                          15.0       6
# Cap'n'Crunch                       12.0      12
# Cinnamon Toast Crunch              13.0       9
# Cocoa Puffs                        12.0      13
# Corn Flakes                        21.0       2
# Count Chocula                      12.0      13
# Cream of Wheat (Quick)             21.0       0
# Crispy Wheat & Raisins             11.0      10
# Froot Loops                        11.0      13
# Frosted Mini-Wheats                14.0       7
# Fruitful Bran                      14.0      12
# Golden Crisp                       11.0      15
# Grape Nuts Flakes                  15.0       5
# Great Grains Pecan                 13.0       4
# Honey Nut Cheerios                 11.5      10
# Just Right Crunchy  Nuggets        17.0       6
# Kix                                21.0       3
# Lucky Charms                       12.0      12
# Muesli Raisins; Dates; & Almonds   16.0      11
# Mueslix Crispy Blend               17.0      13
# Nut&Honey Crunch                   15.0       9
# Nutri-grain Wheat                  18.0       2
# Post Nat. Raisin Bran              11.0      14
# Puffed Rice                        13.0       0
# Quaker Oat Squares                 14.0       6
# Raisin Bran                        14.0      12
# Raisin Squares                     15.0       6
# Rice Krispies                      22.0       3
# Shredded Wheat 'n'Bran             19.0       0
# Smacks                              9.0      15
# Strawberry Fruit Wheats            15.0       5
# Total Raisin Bran                  15.0      14
# Triples                            21.0       3

# %%
# what is this?
cereal.loc[::, ::]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
# ...                          ...     ...     ...       ...    ...     ...
# Triples                     21.0       3      60        25      3     1.0
# Trix                        13.0      12      25        25      2     1.0
# Wheat Chex                  17.0       3     115        25      1     1.0
# Wheaties                    17.0       3     110        25      1     1.0
# Wheaties Honey Gold         16.0       8      60        25      1     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843
# ...                         ...        ...
# Triples                    0.75  39.106174
# Trix                       1.00  27.753301
# Wheat Chex                 0.67  49.787445
# Wheaties                   1.00  51.592193
# Wheaties Honey Gold        0.75  36.187559
#
# [77 rows x 15 columns]
