# %% [markdown]
# # `.query()` method

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### Read CSV and set rating index sorted by labels

# %%
cereal = pd.read_csv("cereal.csv", index_col="name")
cereal.sort_index(inplace=True)
cereal
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %%
# check out the query method documentation first
# cereal.query("mfr == 'K'") quote type agnostic
cereal.query('mfr == "K"')
# Out:
#                             mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran                      K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber     K    C        50        4    0     140   14.0
# Apple Jacks                   K    C       110        2    0     125    1.0
# Corn Flakes                   K    C       100        2    0     290    1.0
# Corn Pops                     K    C       110        1    0      90    1.0
# Cracklin' Oat Bran            K    C       110        3    3     140    4.0
# Crispix                       K    C       110        2    0     220    1.0
# Froot Loops                   K    C       110        2    1     125    1.0
# Frosted Flakes                K    C       110        1    0     200    1.0
# Frosted Mini-Wheats           K    C       100        3    0       0    3.0
# Fruitful Bran                 K    C       120        3    0     240    5.0
# ...

# %%
cereal.query('mfr != "K"')
# Out:
#                                        mfr type  calories  protein  fat  \
# name
# 100% Bran                                N    C        70        4    1
# 100% Natural Bran                        Q    C       120        3    5
# Almond Delight                           R    C       110        2    2
# Apple Cinnamon Cheerios                  G    C       110        2    2
# Basic 4                                  G    C       130        3    2
# Bran Chex                                R    C        90        2    1
# Bran Flakes                              P    C        90        3    0
# Cap'n'Crunch                             Q    C       120        1    2
# Cheerios                                 G    C       110        6    2
# Cinnamon Toast Crunch                    G    C       120        1    3
# Clusters                                 G    C       110        3    2
# Cocoa Puffs                              G    C       110        1    1
# ...

# %%
cereal.query("calories > 100")
# Out:
#                                        mfr type  calories  protein  fat  \
# name
# 100% Natural Bran                        Q    C       120        3    5
# Almond Delight                           R    C       110        2    2
# Apple Cinnamon Cheerios                  G    C       110        2    2
# Apple Jacks                              K    C       110        2    0
# Basic 4                                  G    C       130        3    2
# Cap'n'Crunch                             Q    C       120        1    2
# Cheerios                                 G    C       110        6    2
# Cinnamon Toast Crunch                    G    C       120        1    3
# Clusters                                 G    C       110        3    2
# Cocoa Puffs                              G    C       110        1    1
# Corn Chex                                R    C       110        2    0
# Corn Pops                                K    C       110        1    0
# ...

# %%
cereal.query('mfr == "K" and calories > 100')
# Out:
#                             mfr type  calories  protein  fat  sodium  fiber  \
# name
# Apple Jacks                   K    C       110        2    0     125    1.0
# Corn Pops                     K    C       110        1    0      90    1.0
# Cracklin' Oat Bran            K    C       110        3    3     140    4.0
# Crispix                       K    C       110        2    0     220    1.0
# Froot Loops                   K    C       110        2    1     125    1.0
# Frosted Flakes                K    C       110        1    0     200    1.0
# Fruitful Bran                 K    C       120        3    0     240    5.0
# Just Right Crunchy  Nuggets   K    C       110        2    1     170    1.0
# Just Right Fruit & Nut        K    C       140        3    1     170    2.0
# Mueslix Crispy Blend          K    C       160        3    2     150    3.0
# Nut&Honey Crunch              K    C       120        2    1     190    0.0
# ...

# %%
cereal.query('mfr == "K" or calories > 100')
# Out:
#                                        mfr type  calories  protein  fat  \
# name
# 100% Natural Bran                        Q    C       120        3    5
# All-Bran                                 K    C        70        4    1
# All-Bran with Extra Fiber                K    C        50        4    0
# Almond Delight                           R    C       110        2    2
# Apple Cinnamon Cheerios                  G    C       110        2    2
# Apple Jacks                              K    C       110        2    0
# Basic 4                                  G    C       130        3    2
# Cap'n'Crunch                             Q    C       120        1    2
# Cheerios                                 G    C       110        6    2
# Cinnamon Toast Crunch                    G    C       120        1    3
# Clusters                                 G    C       110        3    2
# Cocoa Puffs                              G    C       110        1    1
# ...

# %%
cereal.query('mfr in ["K", "G"]')
# Out:
#                             mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran                      K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber     K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios       G    C       110        2    2     180    1.5
# Apple Jacks                   K    C       110        2    0     125    1.0
# Basic 4                       G    C       130        3    2     210    2.0
# Cheerios                      G    C       110        6    2     290    2.0
# Cinnamon Toast Crunch         G    C       120        1    3     210    0.0
# Clusters                      G    C       110        3    2     140    2.0
# Cocoa Puffs                   G    C       110        1    1     180    0.0
# Corn Flakes                   K    C       100        2    0     290    1.0
# Corn Pops                     K    C       110        1    0      90    1.0
# ...

# %%
cereal.query('mfr not in ["K", "G"]')
# Out:
#                                        mfr type  calories  protein  fat  \
# name
# 100% Bran                                N    C        70        4    1
# 100% Natural Bran                        Q    C       120        3    5
# Almond Delight                           R    C       110        2    2
# Bran Chex                                R    C        90        2    1
# Bran Flakes                              P    C        90        3    0
# Cap'n'Crunch                             Q    C       120        1    2
# Corn Chex                                R    C       110        2    0
# Cream of Wheat (Quick)                   N    H       100        3    0
# Double Chex                              R    C       100        2    0
# Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# Fruity Pebbles                           P    C       110        1    1
# Golden Crisp                             P    C       100        2    0
# ...
