# %% [markdown]
# # `.drop( )` method

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### Read CSV and set rating index sorted by labels

# %%
cereal = pd.read_csv("cereal.csv", index_col="name")
cereal.sort_index(inplace=True)
cereal
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Drop a row from a DataFrame

# %%
# cereal.drop("All-Bran", inplace=True)
cereal.drop("All-Bran")
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Drop multiple rows

# %%
# cereal.drop(["Trix", "Triples"], inplace=True)
cereal.drop(["Trix", "Triples"])
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Total Raisin Bran           G    C       140        3    1     190    4.0
# Total Whole Grain           G    C       100        3    1     200    3.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Remove columns

# %%
# cereal.drop(["mfr", "type"], axis = 1, inplace=True)
cereal.drop(["mfr", "type"], axis = "columns")
# Out:
#                            calories  protein  fat  sodium  fiber  carbo  \
# name
# 100% Bran                        70        4    1     130   10.0    5.0
# 100% Natural Bran               120        3    5      15    2.0    8.0
# All-Bran                         70        4    1     260    9.0    7.0
# All-Bran with Extra Fiber        50        4    0     140   14.0    8.0
# Almond Delight                  110        2    2     200    1.0   14.0
# ...                             ...      ...  ...     ...    ...    ...
# Triples                         110        2    1     250    0.0   21.0
# Trix                            110        1    1     140    0.0   13.0
# Wheat Chex                      100        3    1     230    3.0   17.0
# Wheaties                        100        3    1     200    3.0   17.0
# Wheaties Honey Gold             110        2    1     200    1.0   16.0
#
#                            sugars  potass  vitamins  shelf  weight  cups  \
# name
# ...

# %% [markdown]
# ### Keeping it Pythonic

# %%
# you can also use the python del keyword: no inplace needed
del cereal["calories"]

# %%
cereal
# Out:
#                           mfr type  protein  fat  sodium  fiber  carbo  \
# name
# 100% Bran                   N    C        4    1     130   10.0    5.0
# 100% Natural Bran           Q    C        3    5      15    2.0    8.0
# All-Bran                    K    C        4    1     260    9.0    7.0
# All-Bran with Extra Fiber   K    C        4    0     140   14.0    8.0
# Almond Delight              R    C        2    2     200    1.0   14.0
# ...                        ..  ...      ...  ...     ...    ...    ...
# Triples                     G    C        2    1     250    0.0   21.0
# Trix                        G    C        1    1     140    0.0   13.0
# Wheat Chex                  R    C        3    1     230    3.0   17.0
# Wheaties                    G    C        3    1     200    3.0   17.0
# Wheaties Honey Gold         G    C        2    1     200    1.0   16.0
#
#                            sugars  potass  vitamins  shelf  weight  cups  \
# name
# ...
