# %% [markdown]
# # Customizing visualizations

# %% [markdown]
# ### Import libraries

# %%
import pandas
from pandas_datareader import data

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Get Bitcoin cryptocurrency data

# %%
# zoom in for a closer look starting on 2022-01-01 to today
btc = data.DataReader(name = "BTC-USD", data_source = "yahoo", start = "2022-01-01")
btc
# Out:
#                     High           Low          Open         Close  \
# Date
# 2022-01-01  47827.312500  46288.484375  46311.746094  47686.812500
# 2022-01-02  47881.406250  46856.937500  47680.925781  47345.218750
# 2022-01-03  47510.726562  45835.964844  47343.542969  46458.117188
# 2022-01-04  47406.546875  45752.464844  46458.851562  45897.574219
# 2022-01-05  46929.046875  42798.222656  45899.359375  43569.003906
# ...                  ...           ...           ...           ...
# 2022-03-12  39308.597656  38772.535156  38794.464844  38904.011719
# 2022-03-13  39209.351562  37728.144531  38884.726562  37849.664062
# 2022-03-14  39742.500000  37680.734375  37846.316406  39666.753906
# 2022-03-15  39794.628906  38310.210938  39664.250000  39338.785156
# 2022-03-17  41286.285156  40887.277344  41139.304688  41051.855469
#
#                   Volume     Adj Close
# Date
# 2022-01-01  2.458267e+10  47686.812500
# 2022-01-02  2.795157e+10  47345.218750
# 2022-01-03  3.307163e+10  46458.117188
# 2022-01-04  4.249468e+10  45897.574219
# 2022-01-05  3.685108e+10  43569.003906
# ...                  ...           ...
# 2022-03-12  1.461645e+10  38904.011719
# 2022-03-13  1.730075e+10  37849.664062
# 2022-03-14  2.432216e+10  39666.753906
# 2022-03-15  2.393400e+10  39338.785156
# 2022-03-17  3.525516e+10  41051.855469
#
# [75 rows x 6 columns]

# %%
# https://fivethirtyeight.com/
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")

# %%
btc[["Open", "Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("ggplot")
btc[["Open", "Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("dark_background")
btc[["Open", "Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("seaborn-notebook")
btc[["Open", "Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("seaborn-poster")
btc[["Open", "Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# For accesibility
# Achromatopsia is also known as “complete color blindness” 
# and is the only type that fully lives up to the term 
# “color blind”. It is extremely rare, however, those who have achromatopsia only see the world in shades of grey, black and white.
plt.style.use("grayscale")
btc[["Open", "Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("seaborn-talk")
btc[["Open", "Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("fast")
btc[["Open", "Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# For accesibility
plt.style.use("colorblind10")
btc[["Open", "Close"]].plot()plt.style.available

# For accesibility
# Achromatopsia is also known as “complete color blindness” 
# and is the only type that fully lives up to the term 
# “color blind”. It is extremely rare, however, those who have achromatopsia only see the world in shades of grey, black and white.
plt.style.use("grayscale")
btc[["Open", "Close"]].plot()

plt.style.use("seaborn-talk")
btc[["Open", "Close"]].plot()

plt.style.use("fast")
btc[["Open", "Close"]].plot()
